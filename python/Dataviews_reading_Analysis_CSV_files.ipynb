# %% [markdown]
# **Title**: Reading CSV files from Analysis containers within Dataviews
#
# **Date**:  February 16th 2023
#
# **Description**:
# This notebook shows the approach for loading CSV files into a dataview.
# See the online SDK help for more details: https://flywheel-io.gitlab.io/product/backend/sdk/branches/master/python/data_views.html#files
#
#
# # Requirements:
# - Flywheel v16.8 or higher

# %% [markdown]
# # Install and Import Dependencies

# %%
# !pip install flywheel-sdk

# %%
import pandas as pd
import flywheel
from getpass import getpass

# %%
try:
    with open("api_key.txt") as file:
      api_key = file.read()
except FileNotFoundError:
    api_key = getpass("Enter your Flywheel API Key:")
    with open("api_key.txt",'w') as file:
      file.write(api_key)

# %% [markdown]
# # Flywheel API Key and Client

# %%
fw = flywheel.Client(api_key)
self = fw.get_current_user()
config = fw.get_config()
print('I am %s %s, connected to %s.' % (self.firstname, self.lastname, config['site']['api_url']))
version = fw.get_version()
print('Flywheel release: %s\nCLI version: %s\nDatabase version: %s' % (version.flywheel_release, version.cli_version, version.database))

print("API Docs:", config['site']['api_url']+"/docs")

# %% [markdown]
# # Locate the project

# %%
project = fw.lookup("ml/ADNI")

# %% [markdown]
# ## What columns do we want from the csv file?
# Since the CSV files will be in Flywheel we will download one and use the columns in it.  We will assume they are all the same in terms of columns.

# %%
csv_columns= ['Container','Name','Status','Origin Path','Export Path','Found Files','Created Files','Failed Files']

# %% [markdown]
# # Create the dataview

# %% [markdown]
# ## Define metadata to return in dataview
# For this example, we only want to get the subject label and session label

# %%
columns = ['subject.label',
           'session.label' ]

# %% [markdown]
# ## Construct Dataview object
# In the example below, we are using `flywheel.ViewBuilder` to build a Dataview object. This is where you specify the Dataview lable, columns you wish to have in your Dataview and more.

# %%
# Specify the dataview
builder = flywheel.ViewBuilder(label='SDK Analysis CSV Aggregation',
                               columns = columns,
                               container='session', #Needed for file metadata
                               #analysis_label='',
                               analysis_gear_name = 'session-export',
                               filename='*.csv', # Needed for file metadata
                               match='newest',
                               process_files=True,
                               include_ids=False,
                               include_labels=False,
                               sort=False,
                              )

# %% [markdown]
# ### Notes: Use `file_match()` method to return the newest file if there are duplicates in the match.
#
# Example:
# ```python
# builder.file_match('newest')
# ```

# %% [markdown]
# ## Add our CSV columns to the builder

# %%
for c in csv_columns:
    builder.file_column(c)

# %% [markdown]
# ## Create the dataview specification

# %%
sdk_dataview = builder.build()

# %% [markdown]
# ## Create the Dataview in Flywheel

# %%
view_id = fw.add_view(project.id, sdk_dataview)

# %%
#Create the dataview and execute it, waiting for return
#This may take 5-10 minutes
df = fw.read_view_dataframe(sdk_dataview, project.id)

# %%
df
# Out:
#       subject.label          session.label    Container  \
# 0        002_S_0295  2006-11-02_08_16_44.0      subject
# 1        002_S_0295  2006-11-02_08_16_44.0      session
# 2        002_S_0295  2006-11-02_08_16_44.0  acquisition
# 3        002_S_0295  2006-11-02_08_16_44.0  acquisition
# 4        016_S_6381                     y2      subject
# ...             ...                    ...          ...
# 15799    941_S_6580                     y1         None
# 15800    941_S_6580                     y2         None
# 15801    941_S_6581                     sc         None
# 15802    941_S_6581                     y2         None
# 15803    941_S_6803                     sc         None
#
#                          Name   Status  \
# 0                  002_S_0295  created
# 1       2006-11-02_08_16_44.0  created
# 2            Hippocampal_Mask  created
# 3      MIDAS_Whole_Brain_Mask  created
# 4                  016_S_6381  created
# ...                       ...      ...
# 15799                    None     None
# 15800                    None     None
# 15801                    None     None
# 15802                    None     None
# 15803                    None     None
#
#                                              Origin Path  \
# 0                                     ml/ADNI/002_S_0295
# 1               ml/ADNI/002_S_0295/2006-11-02_08_16_44.0
# 2      ml/ADNI/002_S_0295/2006-11-02_08_16_44.0/Hippo...
# 3      ml/ADNI/002_S_0295/2006-11-02_08_16_44.0/MIDAS...
# 4                                     ml/ADNI/016_S_6381
# ...                                                  ...
# 15799                                               None
# 15800                                               None
# 15801                                               None
# 15802                                               None
# 15803                                               None
#
#                                              Export Path Found Files  \
# 0                          qian/export_adni_1/002_S_0295
# 1      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 2      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 3      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 4                 nicolas/ADNI-perimeter-test/016_S_6381
# ...                                                  ...         ...
# 15799                                               None        None
# 15800                                               None        None
# 15801                                               None        None
# 15802                                               None        None
# 15803                                               None        None
#
#                                            Created Files Failed Files errors
# 0
# 1
# 2      ('ADNI_002_S_0295_MR_Hippocampal_Mask_Hi_20080...
# 3      ('ADNI_002_S_0295_MR_MIDAS_Whole_Brain_Mask_Br...
# 4
# ...                                                  ...          ...    ...
# 15799                                               None         None
# 15800                                               None         None
# 15801                                               None         None
# 15802                                               None         None
# 15803                                               None         None
#
# [15804 rows x 11 columns]

# %%
with pd.option_context('display.max_rows',100):
    display(df)
# Out:
#       subject.label          session.label    Container  \
# 0        002_S_0295  2006-11-02_08_16_44.0      subject
# 1        002_S_0295  2006-11-02_08_16_44.0      session
# 2        002_S_0295  2006-11-02_08_16_44.0  acquisition
# 3        002_S_0295  2006-11-02_08_16_44.0  acquisition
# 4        016_S_6381                     y2      subject
# ...             ...                    ...          ...
# 15799    941_S_6580                     y1         None
# 15800    941_S_6580                     y2         None
# 15801    941_S_6581                     sc         None
# 15802    941_S_6581                     y2         None
# 15803    941_S_6803                     sc         None
#
#                          Name   Status  \
# 0                  002_S_0295  created
# 1       2006-11-02_08_16_44.0  created
# 2            Hippocampal_Mask  created
# 3      MIDAS_Whole_Brain_Mask  created
# 4                  016_S_6381  created
# ...                       ...      ...
# 15799                    None     None
# 15800                    None     None
# 15801                    None     None
# 15802                    None     None
# 15803                    None     None
#
#                                              Origin Path  \
# 0                                     ml/ADNI/002_S_0295
# 1               ml/ADNI/002_S_0295/2006-11-02_08_16_44.0
# 2      ml/ADNI/002_S_0295/2006-11-02_08_16_44.0/Hippo...
# 3      ml/ADNI/002_S_0295/2006-11-02_08_16_44.0/MIDAS...
# 4                                     ml/ADNI/016_S_6381
# ...                                                  ...
# 15799                                               None
# 15800                                               None
# 15801                                               None
# 15802                                               None
# 15803                                               None
#
#                                              Export Path Found Files  \
# 0                          qian/export_adni_1/002_S_0295
# 1      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 2      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 3      qian/export_adni_1/002_S_0295/2006-11-02_08_16...
# 4                 nicolas/ADNI-perimeter-test/016_S_6381
# ...                                                  ...         ...
# 15799                                               None        None
# 15800                                               None        None
# 15801                                               None        None
# 15802                                               None        None
# 15803                                               None        None
#
#                                            Created Files Failed Files errors
# 0
# 1
# 2      ('ADNI_002_S_0295_MR_Hippocampal_Mask_Hi_20080...
# 3      ('ADNI_002_S_0295_MR_MIDAS_Whole_Brain_Mask_Br...
# 4
# ...                                                  ...          ...    ...
# 15799                                               None         None
# 15800                                               None         None
# 15801                                               None         None
# 15802                                               None         None
# 15803                                               None         None
#
# [15804 rows x 11 columns]

# %% [markdown]
# ## Clean up the Flywheel objects

# %% [markdown]
# ### Delete the Dataview

# %%
for dv in fw.get_views(project.id):
    print(dv.label,end='---> ')
    if dv.label in ['SDK Analysis CSV Aggregation']:
        fw.delete_view(dv.id)
        print('deleted')
    else:
        print('remaining')
# Out:
# FileDV---> remaining
# jen testing promoted---> remaining
# Alex test data view sitewide---> remaining
# jen6---> remaining
# SDK Data View---> deleted
